# %%
import pandas as pd
import os

# %%
chunk_size = 10000  # Adjust the chunk size as needed
chunks = pd.read_csv('chunk_1.csv', delimiter=None, chunksize=chunk_size)

for chunk in chunks:
    # Process each chunk as needed
    print(chunk.head())  # For example, printing the first few rows of each chunk
# Out:
# C:\Users\Dhananjay\AppData\Local\Temp\ipykernel_15036\3369284585.py:4: DtypeWarning: Columns (17,72,80,87,89,90,91,93,94,95,96,97,98,99,100,101,102,103,104,105,106,163,171,174,175,178,179,181,182,183,185,186,187,189,190,193,194,197,198,199,201,205,324,325,326,327,328) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunks:
#           NPI  Entity Type Code  Replacement NPI  \
# 0  1679576722               1.0              NaN
# 1  1588667638               1.0              NaN
# 2  1497758544               2.0              NaN
# 3  1306849450               NaN              NaN
# 4  1215930367               1.0              NaN
#
#   Employer Identification Number (EIN)  \
# 0                                  NaN
# 1                                  NaN
# 2                            <UNAVAIL>
# 3                                  NaN
# 4                                  NaN
#
#   Provider Organization Name (Legal Business Name)  \
# ...

# %%
count=0
for chunk in chunks:
    # Process each chunk as needed
    #chunk.head()  
    count+=1
    chunk.head()  
    if count==2:
        break

# %%
df.to_csv("NPI_sample.csv")

# %%
for chunk in chunks:
    # Process each chunk as needed
    print(chunk.head())

# %%
import pandas as pd

# Specify the number of rows to read (1000 in this case)
n_rows = 1000

# Read the first 1000 rows of the CSV file into a DataFrame
df = pd.read_csv('chunk_1.csv', delimiter=None, nrows=n_rows)

# Now you have a DataFrame containing the first 1000 rows of your CSV file
print(df)
# Out:
#             NPI  Entity Type Code  Replacement NPI  \
# 0    1679576722               1.0              NaN
# 1    1588667638               1.0              NaN
# 2    1497758544               2.0              NaN
# 3    1306849450               NaN              NaN
# 4    1215930367               1.0              NaN
# ..          ...               ...              ...
# 995  1417950635               1.0              NaN
# 996  1326041542               1.0              NaN
# 997  1235132457               1.0              NaN
# 998  1144223363               1.0              NaN
# 999  1053314278               1.0              NaN
#
#     Employer Identification Number (EIN)  \
# 0                                    NaN
# 1                                    NaN
# 2                              <UNAVAIL>
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 995                                  NaN
# ...

# %%
df
# Out:
#             NPI  Entity Type Code  Replacement NPI  \
# 0    1679576722               1.0              NaN
# 1    1588667638               1.0              NaN
# 2    1497758544               2.0              NaN
# 3    1306849450               NaN              NaN
# 4    1215930367               1.0              NaN
# ..          ...               ...              ...
# 995  1417950635               1.0              NaN
# 996  1326041542               1.0              NaN
# 997  1235132457               1.0              NaN
# 998  1144223363               1.0              NaN
# 999  1053314278               1.0              NaN
#
#     Employer Identification Number (EIN)  \
# 0                                    NaN
# 1                                    NaN
# 2                              <UNAVAIL>
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 995                                  NaN
# ...

# %%
df.to_csv('NPI_sample.csv')
